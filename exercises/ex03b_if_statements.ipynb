# %% [markdown]
# ## Boolean Expressions & Comparison Operators
#
# For exercises 1 to 3, you should not use an if-statement, simply print the result of the comparison
#
# ### Exercise 1
# Write a program that asks the user to enter their age. Print True if the age is greater than 18, otherwise print False.

# %%
age = int(input('Input yur age: '))
print(f'Is ypur age over 18: {18 < age}')
# Out:
# Is ypur age over 18: False

# %% [markdown]
# ### Exercise 2
# Ask the user to input two numbers. Print True if the first number is strictly less than the second.

# %%
num_1 = int(input('put a number: '))
num_2 = int(input('put a number: '))
result = num_1 < num_2
print(f'Is number {num_1} less than number {num_2}. Result: {result}')
# Out:
# Is number 3 less than number 4. Result: True

# %% [markdown]
# ### Exercise 3
# Given a variable x = 10, write Boolean expressions that evaluate to:
#
# True if x is equal to 10
#
# True if x is not equal to 5
#
# True if x is greater than or equal to 7

# %%
x = 10 
print(f'if equal to 10 {x == 10}\nif x != 5 {x != 5}\nif x >= 7 {x >= 7}')
# Out:
# if equal to 10 True
#  if x != 5 True
# if x >= 7 True

# %% [markdown]
# ## Simple If Statement
#
# Exercises 4-6 must not have a False block i.e. it must only have a True block
#
# ### Exercise 4
# Ask the user to enter a number. If the number is positive, print "<<number >> is positive number".

# %%
number = float(input('Any number '))
if number > 0:
    print(f'{number} is positive number')
# Out:
# 44.0 is positive number

# %% [markdown]
# ### Exercise 5
#
# Write the statement to prompts the user for an hourly pay rate.
# If the value entered is less than $7.50, display an appropriate error message

# %%
salary_per_hour = float(input('Wjat is yout salary per hour? '))
if salary_per_hour < 7.5:
    print('Your salary is too low')
# Out:
# 3232.0

# %% [markdown]
# ### Exercise 6
# Write a program that checks whether a string entered by the user is empty. If it is not empty, print "You entered: string".

# %%
string = input('Any messege: ')
if len(string) != 0:
    print('You entered: string')

# %% [markdown]
# #### Exercise 7
# Write a program that asks the user to input a test score. If the score is greater than or equal to 90 prints:
# 'Your score of 91 is Excellent'

# %%
your_score = int(input('Your score is: '))
if your_score >= 90:
    print(f'Your score of {your_score} is Excellent')
# Out:
# Your score of 99 is Excellent

# %% [markdown]
# ## If-Else Statement
#
# Exercises 7-10 will have both a True block and a False block
#
# ### Exercise 7
# Ask the user to enter an integer. Print "Even" if the number is even, otherwise print "Odd".

# %%
whole_number = int(input('Input number: '))
if whole_number / 2 == 0:
    print(f'The number {whole_number} is even')
else:
    print(f'The number {whole_number} is odd')
# Out:
# The number 45 is odd

# %% [markdown]
# ### Exercise 8
# Write a program that ask for a user name.
# -   if the input is empty, print `You must enter a username`
# -   otherwise, print `Welcome Â«usernameÂ»`

# %%
user_name = input('What is your name? ')
if len(user_name) == 0:
    print('You must enter a username')
else:
    print(f'Welcome {user_name}')
# Out:
# Welcome fefer

# %% [markdown]
# ### Exercise 9
# Write a program that asks for a password. If the entered password is "Python123", print "Access granted". Otherwise, print "Access denied".

# %%
password = input('Password: ')
if password == 'Python123':
    print('Sccess granted')
else:
    print('Access denied')
# Out:
# Sccess granted

# %% [markdown]
# ### Exercise 9
# Write the statement that prompts the user for an hourly pay rate and hours worked.
# Compute and display gross pay (hours times pay rate), withholding tax, and net pay
# (gross pay minus withholding tax).
# Withholding tax is computed as a percentage of gross pay based on the following:
#
# | Gross Pay	                 | Withholding Percentage |
# |----------------------------|------------------------|
# | Up to and including 300.00 |	10%                   |
# | More than300.00	         |   12%                  |

# %%
hours = float(input('Hours total a week: '))
per_hour_salary = round(float(input('Per hour salary: ')),2)
gross_pay = round(hours * per_hour_salary, 2)
afte_tax = None
print(f'Your gross pay is: ${gross_pay:.2f}')
if gross_pay <= 300:
    afte_tax = gross_pay * 0.9
else:
    afte_tax = gross_pay * 0.88
print(f'Your salary after tax is: ${afte_tax}')
# Out:
# Your gross pay is: $9690.00
# Your salary after tax is: $8527.2

# %% [markdown]
# ### Exercise 10
#
# If money is left in a particular bank for more than 5 years, the interest rate given by the bank is 7.5%, else the interest rate is 5.4%. Write the statements that prompt the user for the number of years that the money was left in the bank and display the appropriate interest rate depending on the value input. How many runs should you make to very that it works correctly?

# %%
LONG_TERM = 7.5 / 100
SHORT_TERM = 5.4 / 100
month_diposit = int(input('For how many month do you want to dipisit? ')) # total months 
deposit_emont = round(float(input('How much would you like to diposit? '))) # money deposit 

curent_rate = None # per month rate 

if month_diposit / 12 < 5:
    curent_rate = SHORT_TERM / 12
else:
    curent_rate = LONG_TERM / 12 

income_total =  deposit_emont + deposit_emont * curent_rate * month_diposit# \Totla = P + P *  r(rait) * n(months)

print(f'Your total deposit from ${deposit_emont:.2f} incressed by ${income_total - deposit_emont:.2f} and now it is: ${income_total:.2f}')
# Out:
# 0.054000000000000006
# Your total deposit from $1000.00 incressed by $54.00 and now it is: $1054.00

# %% [markdown]
# ## Nested If / If-Elif-Else
#
# Exercises 11-13 will have both True and False blocks, and will have an if=statement in either the True or False block or both.
#
# ### Exercise 11
# Write a program that asks the user for a grade (A, B, C, D, F). Using if-elif-else, print the corresponding message:
#
# -   'Excellent' for A
# -   'Good' for B
# -   'Average' for C
# -   'Poor' for D
# -   'Fail' for F

# %%
grade = input('What is your grade? ').upper()

if grade == 'A': print('Excellent')
elif grade == 'B': print('Good')
elif grade == 'C': print('Average')
elif grade == 'D': print('Poor')
elif grade == 'F': print('Fail')
else: print('You have 0 marks')
# Out:
# You have 0 marks

# %% [markdown]
# ### Exercise 12
# Ask the user for their age and years of service
# -   if age is 65 or older, print `Eligible for pension`
# -   otherwise check if service is more than 10 year, print `Eligible for pension`
# -   othersize, print `Not eligible`

# %%
age = int(input('Your age: '))
service_years = int(input('How long have you use the service: '))

if age >= 65: print('Eligible for pension')
elif service_years > 10: print('Eligible for pension')
else: print('Not eligible')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 age = int(input('Your age: '))
# ----> 2 service_years = int(input('How long have you use the service: '))
#       3
#       4 if age >= 65: print('Eligible for pension')
#       5 elif service_years > 10: print('Eligible for pension')
#
# File ~/.local/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/.local/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### Exercise 12
# Ask the user to enter a number. If the number is positive, check if itâ€™s even or odd and print the result. If itâ€™s negative, print "Negative number".

# %%
sighn = None
odd_even = None

number = int(input('Chose any whole number: '))

if number < 0:
    sighn = 'Negativ'
    if number % 2 == 0: odd_even = 'Even'
    else: odd_even = 'Odd'
elif number > 0:
    sighn = 'Pasitiv'
    if number % 2 == 0: odd_even = 'Even'
    else: odd_even = 'Odd'
else:
    print('Number is 0')


if number != 0:
    print(f'Number {number} is {sighn} and it is {odd_even}')
# Out:
# Number 10 is Pasitiv and it is Even

# %% [markdown]
# ### Exercise 13
# Write the statements to prompt the user for two integers and a letter. Do the following:
# -   If the letter is A add the two numbers
# -   If the letter is S subtract the second from the first
# -   If the letter is M multiply the two numbers
# -   Otherwise divide the first number by the second
#
# P.S. This problem can be solved more elegantly using the match-statement

# %%
in_one = int(input('Input any whole number: '))
in_two = int(input('Input any whole number: '))
any_letter = input('Chose any one letter: ').upper()
result = None

if any_letter == 'A': result= in_one + in_two
elif any_letter == 'S': result = in_one - in_two
elif any_letter == 'M': result = in_one * in_two
else:
    if in_two != 0: result = in_one / in_two

if result == None:
    print('No result becose cant devide on 0')
print(result)
# Out:
# None

# %% [markdown]
# ## Logical Operators (and, or)
#
# ### Exercise 14
# Ask the user to input a year. Print "Leap year" if:
#
# The year is divisible by 4 and not divisible by 100, or divisible by 400.
# Otherwise, print "Not a leap year".

# %%
year = int(input('Put a any year: '))
leap_year = None 

if year % 4 == 0:
    if year % 100 != 0:
        leap_year = 'Leap year'
    else: leap_year = 'Leap year'
elif year % 400 == 0: leap_year = 'Leap year'
else:
    leap_year = 'Not a leap year'
    
print(f'year: {year} is a {leap_year}')
# Out:
# year: 1000 is a Leap year

# %% [markdown]
# ### Exercise 15
# Write a program that asks for two numbers. Print "Both positive" if both are greater than 0, "At least one positive" if one or both are greater than 0, otherwise print "No positives".
#
# N.B. This exercise may be solve in multiple ways.

# %%
# num_one = int(input('Any number: '))
# nump_twp = int(input('Any number: '))

pair_of_numbers = [int(input('Any number: ')), int(input('Any number: '))]
result = 0
for i in pair_of_numbers:
    if i > 0:
        result += 1

if result == 0: print('No positiv numbers')
elif result == 1: print('One number is posotiv')
elif result == 2: print('Both numbers are positiv.')
# Out:
# Both numbers are positiv.
